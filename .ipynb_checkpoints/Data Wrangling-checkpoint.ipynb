# %%
import pandas as pd
data = pd.read_csv(r"mysmartprice.csv")
#used open source boston dataset

# %%
data
#printed data
# Out:
#                  product name                           processor price  \
# 0                 Vivo V23 5G  MediaTek Dimensity 920 MT6877T Processor
# 1             Vivo V23 Pro 5G  MediaTek Dimensity 1200 MT6893 Processor
# 2              OnePlus Nord 2  MediaTek Dimensity 1200 MT6893 Processor
# 3    Xiaomi Redmi Note 11T 5G   MediaTek Dimensity 810 MT6833 Processor
# 4      Xiaomi 11i HyperCharge  MediaTek Dimensity 920 MT6877T Processor
# ..                        ...                                       ...
# 178          Realme 8 5G 64GB   MediaTek Dimensity 700 MT6833 Processor
# 179     Xiaomi Mi 10T 8GB RAM         Qualcomm Snapdragon 865 Processor
# 180            Huawei P40 Pro          HiSilicon Kirin 990 5G Processor
# 181              IQOO 7 256GB         Qualcomm Snapdragon 870 Processor
# 182     Samsung Galaxy Fold 2    Qualcomm Snapdragon 865 Plus Processor
#
#                       camera specs rear          camera specs front  \
# ...

# %%
df = pd.DataFrame(data)
#assigned dataframes to variable df.

# %%
df.isnull()
#checked if any field in dataset is empty
# Out:
#      product name  processor price  camera specs rear  camera specs front  \
# 0           False            False              False               False
# 1           False            False              False               False
# 2           False            False              False               False
# 3           False            False              False               False
# 4           False            False              False               False
# ..            ...              ...                ...                 ...
# 178         False            False              False               False
# 179         False            False              False               False
# 180         False            False              False               False
# 181         False            False              False               False
# 182         False            False              False               False
#
#      display size  ram of phone  storage  battery  android version  \
# ...

# %%
df.isnull().sum()
# Out:
# product name                    0
# processor price                 0
# camera specs rear               0
# camera specs front              0
# display size                    0
# ram of phone                    0
# storage                         0
# battery                         0
# android version                 0
# score by smartprice            29
# first site                     56
# price in first site            56
# second site                    92
# price in second site           92
# Price of product(available)     0
# dtype: int64

# %%
df.describe()
# Out:
#        score by smartprice
# count           154.000000
# mean              7.973377
# std               0.354069
# min               7.000000
# 25%               7.800000
# 50%               8.000000
# 75%               8.200000
# max               8.800000

# %%
df.shape
#dimensions of dataset.
# Out:
# (183, 15)

# %%
df.dtypes
# Out:
# product name                    object
# processor price                 object
# camera specs rear               object
# camera specs front              object
# display size                    object
# ram of phone                    object
# storage                         object
# battery                         object
# android version                 object
# score by smartprice            float64
# first site                      object
# price in first site             object
# second site                     object
# price in second site            object
# Price of product(available)     object
# dtype: object

# %%
df["product name"]=df["product name"].astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SHRIPA~1\AppData\Local\Temp/ipykernel_14248/559853884.py in <module>
# ----> 1 df["product name"]=df["product name"].astype("float")
#
# c:\users\shripad joshi\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# c:\users\shripad joshi\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# ...

# %%
df["android version"]=df["android version"].astype("|S")

# %%
df.dtypes
# Out:
# product name                      |S35
# processor price                 object
# camera specs rear               object
# camera specs front              object
# display size                    object
# ram of phone                    object
# storage                         object
# battery                         object
# android version                   |S18
# score by smartprice            float64
# first site                      object
# price in first site             object
# second site                     object
# price in second site            object
# Price of product(available)     object
# dtype: object
